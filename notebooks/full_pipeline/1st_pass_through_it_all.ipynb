# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Download / organize dataset
#
# non-faces (class 0) vs faces (class 1)

# %% [markdown]
# TODO:
# * Automate this and fix my shitty use of different classes for train and dev
#
# Currently I just manually dropped:
# * private_proof_v1/insect -> datasets/private_proof/train/0_nonface
# * private_proof_v1/face -> datasets/private_proof/train/1_face
# * private_proof_v1/ring -> datasets/private_proof/train/0_nonface
# * private_proof_v1/face_holdout -> datasets/private_proof/dev/1_face

# %% [markdown]
# # Train a substituion (whitebox) model
#
# Use the train/0_nonfaces, train/1_faces classes for training and dev/0_nonfaces, dev/1_faces for evaluation

# %%
used_saved_model = True
saved_model_name = "./1st_pass-20180327T160554/model.ckpt"

# %%
import sys
sys.path.append('../../source')

from pathlib import Path
import numpy as np
import datetime
import keras
from keras import backend
import tensorflow as tf
from tensorflow.python.platform import flags
from keras.models import load_model

from cleverhans.utils_mnist import data_mnist
from cleverhans.utils_tf import model_train, model_eval
from cleverhans.attacks import FastGradientMethod
from cleverhans.utils import AccuracyReport
from cleverhans.utils_keras import cnn_model
from cleverhans.utils_keras import KerasModelWrapper

from data_processing import import_images_from_directories
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
dataset_path = '../../datasets/private_proof_v1'

desired_image_size = (250, 250)

max_images_per_class = 1000

if not used_saved_model:

    X_train, Y_train = import_images_from_directories(
        dataset_path + '/train', 
        resize_shape=desired_image_size, 
        max_images_per_class=max_images_per_class
    )

    print("X_train shape, Y_train shape: {}, {}".format(X_train.shape, Y_train.shape))

X_test, Y_test = import_images_from_directories(
    dataset_path + '/dev', 
    resize_shape=desired_image_size, 
    max_images_per_class=max_images_per_class
)

num_classes = Y_test.shape[1]

print("X_test shape, Y_test shape: {}, {}".format(X_test.shape, Y_test.shape))
# Out:
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_0.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_101.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_111.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_121.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_13.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_15.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_153.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_162.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_171.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_184.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_2.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_21.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_251.jpg, skipping...
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py:882: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_273.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_285.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_308.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_31.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_320.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_326.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_344.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_351.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_366.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_370.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_38.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_444.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_449.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_471.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_474.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_504.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_505.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_52.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_522.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_528.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_546.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_547.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_589.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_592.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_626.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_632.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_64.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_646.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_653.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_654.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_666.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_683.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_687.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_691.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_702.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_708.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_80.jpg, skipping...
# The labels are: {0: '0_nonface', 1: '1_face'}
# X_test shape, Y_test shape: (1706, 250, 250, 3), (1706, 2)

# %%
def evaluate():
    # Evaluate the accuracy of the model on legitimate test examples
    eval_params = {'batch_size': batch_size}
    acc = model_eval(sess, x, y, preds, X_test, Y_test, args=eval_params)
    report.clean_train_clean_eval = acc
    print('Test accuracy on legitimate examples: %0.4f' % acc)

n_epochs = 5
batch_size = 32
learning_rate = 0.001

# Object used to keep track of (and return) key accuracies
report = AccuracyReport()

# Create TF session and set as Keras backend session
sess = tf.Session()

# Set TF random seed to improve reproducibility
tf.set_random_seed(1234)
rng = np.random.RandomState([2017, 8, 30])

keras.backend.set_session(sess)

if keras.backend.image_dim_ordering() != 'tf':
    keras.backend.set_image_dim_ordering('tf')
    print("INFO: '~/.keras/keras.json' sets 'image_dim_ordering' to "
          "'th', temporarily setting to 'tf'")

keras.layers.core.K.set_learning_phase(0)

# Define input TF placeholder
x = tf.placeholder(tf.float32, shape=(None, desired_image_size[0], desired_image_size[1], 3))
y = tf.placeholder(tf.float32, shape=(None, num_classes))

# Define TF model graph
model = cnn_model(img_rows=desired_image_size[0], 
                  img_cols=desired_image_size[1], 
                  channels=3, 
                  nb_filters=64, 
                  nb_classes=num_classes)
preds = model(x)

# Train
train_params = {
    'nb_epochs': n_epochs,
    'batch_size': batch_size,
    'learning_rate': learning_rate
}

saver = tf.train.Saver()

if used_saved_model:
    saver.restore(sess, saved_model_name)
    evaluate()
else:
    model_train(sess, x, y, preds, X_train, Y_train, evaluate=evaluate,
                args=train_params, rng=rng)
    saver.save(sess, "./1st_pass-{}/model.ckpt".format(datetime.datetime.now().strftime('%Y%m%dT%H%M%S')))
# Out:
# INFO:tensorflow:Restoring parameters from ./1st_pass-20180327T160554/model.ckpt
# Test accuracy on legitimate examples: 0.9789

# %% [markdown]
# # Create the image attack using FGSM + our trained subsitution model

# %%
from pathlib import Path
import cv2
from skimage import io
from IPython.display import Image, display
from PIL import Image as pil_image
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Wrap the FGSM attack object around the whitebox subsitution model

# Initialize the Fast Gradient Sign Method (FGSM) attack object and graph
wrap = KerasModelWrapper(model)
fgsm = FastGradientMethod(wrap, sess=sess)

adv_x_weak = fgsm.generate(x, eps=0.05, clip_min=0.0, clip_max=1.0)
adv_x_weak = tf.stop_gradient(adv_x_weak)
preds_adv_weak = model(adv_x_weak)

adv_x_strong = fgsm.generate(x, eps=0.2, clip_min=0.0, clip_max=1.0)
adv_x_strong = tf.stop_gradient(adv_x_strong)
preds_adv_strong = model(adv_x_strong)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/cleverhans/attacks.py:208: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/cleverhans/attacks_tf.py:55: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/cleverhans/utils_tf.py:37: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
def load_image(image_path, resize_shape=None):
    image_path = Path(image_path)
    if resize_shape is None:
        img = pil_image.open(image_path.as_posix()).convert('RGB')
    else:
        img = pil_image.open(image_path.as_posix()).convert('RGB').resize(resize_shape)
    return np.asarray(img) / 255.0

# %%
img = load_image('../../datasets/private_proof_v1/dev/1_face/Aaron_Eckhart_0001.jpg', (250, 250))
plt.imshow(img)

# %%
# Look, it got it right!

print(sess.run(preds, feed_dict={x: np.asarray([img])})[0])
print(np.argmax(sess.run(preds, feed_dict={x: np.asarray([img])})))
# Out:
# [8.003716e-06 9.999920e-01]
# 1

# %%
perturbed_img_weak = sess.run(adv_x_weak, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_weak)

# %%
perturbed_img_strong = sess.run(adv_x_strong, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_strong)

# %%
def attack_images(imgs, adv_x):
    imgs = np.asarray(imgs)
    assert len(imgs.shape) == 4
    assert imgs.shape[1] == imgs.shape[2] == 250
    assert imgs.shape[3] == 3
    assert (0.0 <= imgs).all() and (imgs <= 1.0).all()
    return sess.run(adv_x, feed_dict={x: imgs})

# %%
# Look, it got it wrong on the weak attack!

perturbed_img = attack_images([img], adv_x=adv_x_weak)[0]

print(sess.run(preds, feed_dict={x: np.asarray([perturbed_img])})[0])
print(np.argmax(sess.run(preds, feed_dict={x: np.asarray([perturbed_img])})))
# Out:
# [9.9999857e-01 1.3826747e-06]
# 0

# %%
# Look, it got it wrong on the strong attack!

perturbed_img = attack_images([img], adv_x=adv_x_strong)[0]

print(sess.run(preds, feed_dict={x: np.asarray([perturbed_img])})[0])
print(np.argmax(sess.run(preds, feed_dict={x: np.asarray([perturbed_img])})))
# Out:
# [1.0000000e+00 1.1265779e-26]
# 0

# %%
img = load_image('../../datasets/private_proof_v1/dev/1_face/Alicia_Witt_0001.jpg', (250, 250))
plt.imshow(img)

# %%
perturbed_img_weak = sess.run(adv_x_weak, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_weak)

# %%
perturbed_img_strong = sess.run(adv_x_strong, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_strong)

# %%
img = load_image('../../datasets/private_proof_v1/dev/1_face/Aiysha_Smith_0001.jpg', (250, 250))
plt.imshow(img)

# %%
perturbed_img_weak = sess.run(adv_x_weak, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_weak)

# %%
perturbed_img_strong = sess.run(adv_x_strong, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_strong)

# %%
img = load_image('../../datasets/private_proof_v1/dev/1_face/Andre_Agassi_0020.jpg', (250, 250))
plt.imshow(img)

# %%
perturbed_img_weak = sess.run(adv_x_weak, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_weak)

# %%
perturbed_img_strong = sess.run(adv_x_strong, feed_dict={x: np.asarray([np.asarray(img)])})[0]
plt.imshow(perturbed_img_strong)

# %% [markdown]
# # Create a detector from our subsitution model

# %%
from face_detectors.face_detector import FaceDetector

# %%
class SubsitutionWhitebox(FaceDetector):
    
    def _detect_face(self, img):
        return np.argmax(sess.run(preds, feed_dict={x: np.asarray([img])})) == 1

# %%
sub_wb_detector = SubsitutionWhitebox()

# %%
# Look, it got it right!

img = load_image('../../datasets/private_proof_v1/dev/1_face/Aaron_Eckhart_0001.jpg', (250, 250))

sub_wb_detector.contains_a_face(img)
# Out:
# True

# %%
# Look, it got it wrong!

perturbed_img = attack_images([img], adv_x=adv_x_strong)[0]

sub_wb_detector.contains_a_face(perturbed_img)
# Out:
# False

# %% [markdown]
# # Evaluate remote API face detectors against our image attack

# %%
import io

from PIL import Image as pil_image
from google.cloud import vision
from google.cloud.vision import types
from clarifai.rest import ClarifaiApp
from clarifai.rest import Image as ClImage

from face_detectors.face_detector import FaceDetector

# %%
class GoogleVisionFaceDetector(FaceDetector):
    
    _client = vision.ImageAnnotatorClient()
    
    def _detect_face(self, img):
        # Convert the image to a byte_array
        bytes_buff = io.BytesIO()
        pil_image.fromarray(np.uint8(img * 255.0)).save(bytes_buff, 'PNG')
        img_byte_array = bytes_buff.getvalue()

        # Request
        image = types.Image(content=img_byte_array)
        response = self._client.face_detection(image=image)        
        return len(response.face_annotations) > 0
    
class ClarifaiFaceDetector(FaceDetector):
    
#     _app = ClarifaiApp(api_key='f9c874a9098c4ade9ea857a4b955cee0')
    _app = ClarifaiApp(api_key='cf758cd9528f436c9e63d5b083cdd650')
    _model = _app.models.get("face-v1.3")
    
    def _detect_face(self, img):
        # Convert the image to a byte_array
        bytes_buff = io.BytesIO()
        pil_image.fromarray(np.uint8(img * 255.0)).save(bytes_buff, 'PNG')

        # Request
        image = ClImage(file_obj=bytes_buff)
        results2 = clarifai_vision_detector._model.predict([image])
        return 'regions' in results2['outputs'][0]['data']
    
class ClarifaiFaceDetector(FaceDetector):
    
#     _app = ClarifaiApp(api_key='f9c874a9098c4ade9ea857a4b955cee0')
    _app = ClarifaiApp(api_key='cf758cd9528f436c9e63d5b083cdd650')
    _model = _app.models.get("face-v1.3")
    
    def _detect_face(self, img):
        # Convert the image to a byte_array
        bytes_buff = io.BytesIO()
        pil_image.fromarray(np.uint8(img * 255.0)).save(bytes_buff, 'PNG')

        # Request
        image = ClImage(file_obj=bytes_buff)
        results2 = clarifai_vision_detector._model.predict([image])
        return 'regions' in results2['outputs'][0]['data']

# %%
gc_vision_detector = GoogleVisionFaceDetector()
clarifai_vision_detector = ClarifaiFaceDetector()

# %%
# Look, it got it right!

img = load_image('../../datasets/private_proof_v1/dev/1_face/Aaron_Eckhart_0001.jpg', (250, 250))

gc_vision_detector.contains_a_face(img)
# Out:
# True

# %%
# Look, it got it wrong!

perturbed_img = attack_images([img], adv_x=adv_x_strong)[0]

gc_vision_detector.contains_a_face(perturbed_img)
# Out:
# False

# %%
# Look, it got it right!

img = load_image('../../datasets/private_proof_v1/dev/1_face/Aaron_Eckhart_0001.jpg', (250, 250))

clarifai_vision_detector.contains_a_face(img)
# Out:
# True

# %%
# Look, it got it wrong!

perturbed_img = attack_images([img], adv_x=adv_x_strong)[0]

clarifai_vision_detector.contains_a_face(perturbed_img)
# Out:
# False

# %% [markdown]
# # Evaluate the subsitution model, the local blackbox face detectors, and Google Cloud Vision's API against our image attack

# %%
import sys
sys.path.append('../../source')

from pathlib import Path
import cv2
from IPython.display import Image, display
import dlib
import pandas as pd

from data_processing import import_images_from_directories
from face_detectors import dlib_face_detector, cv2_cascade_face_detector

# %%
dataset_path = '../../datasets/private_proof_v1/dev'

# %%
detectors = {
    'sub_wb': SubsitutionWhitebox(),
    'dlib': dlib_face_detector.DlibFaceDetector(), 
    'cv2': cv2_cascade_face_detector.CV2CascadeFaceDetector(),
    'gc_vision': GoogleVisionFaceDetector(),
    'clarifai': ClarifaiFaceDetector()
}

# %%
def detections(detectors, X):
    num_dets = {}
    for name, d in detectors.items():
        num_dets[name] = d.contains_a_face(X).sum()
    return num_dets, X.shape[0]

# %%
max_images_per_class = 500

index = pd.Index(['sub_wb_face_detections-as_%', 'dlib_face_detections-as_%', 'cv2_face_detections-as_%', 'gc_vision_face_detections-as_%', 'clarifai_face_detections-as_%'])
confusion = pd.DataFrame(index=index, columns=['0_nonface', '1_face', 'weak_fgsm_sub_wb-1_face', 'strong_fgsm_sub_wb-1_face'])
for c in confusion.columns:
    if c == 'weak_fgsm_sub_wb-1_face':
        X, _ = import_images_from_directories(dataset_path, class_labels=['1_face'], resize_shape=(250, 250), max_images_per_class=max_images_per_class)
        X = attack_images(X, adv_x=adv_x_weak)
    elif c == 'strong_fgsm_sub_wb-1_face':
        X, _ = import_images_from_directories(dataset_path, class_labels=['1_face'], resize_shape=(250, 250), max_images_per_class=max_images_per_class)
        X = attack_images(X, adv_x=adv_x_strong)
    else:
        X, _ = import_images_from_directories(dataset_path, class_labels=[c], resize_shape=(250, 250), max_images_per_class=max_images_per_class)
    num_dets, total = detections(detectors, X)
    for key, val in num_dets.items():
        confusion.loc[key + '_face_detections-as_%', c] = 100.0 * val / total
        
confusion
# Out:
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_0.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_101.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_111.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_121.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_13.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_15.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_153.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_162.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_171.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_184.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_2.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_21.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_251.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_273.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_285.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_308.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_31.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_320.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_326.jpg, skipping...
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py:882: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_344.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_351.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_366.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_370.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_38.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_444.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_449.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_471.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_474.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_504.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_505.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_52.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_522.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_528.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_546.jpg, skipping...
# Unable to open file ../../datasets/private_proof_v1/dev/0_nonface/ring_547.jpg, skipping...
# The labels are: {0: '0_nonface'}
# The labels are: {0: '1_face'}
# The labels are: {0: '1_face'}
# The labels are: {0: '1_face'}
#                                0_nonface 1_face weak_fgsm_sub_wb-1_face  \
# sub_wb_face_detections-as_%      4.30108   99.6                      11
# dlib_face_detections-as_%              0   99.6                    97.8
# cv2_face_detections-as_%         6.45161   99.8                      98
# gc_vision_face_detections-as_%  0.215054    100                    99.6
# clarifai_face_detections-as_%   0.860215    100                    99.8
#
#                                strong_fgsm_sub_wb-1_face
# sub_wb_face_detections-as_%                          0.4
# dlib_face_detections-as_%                           28.8
# cv2_face_detections-as_%                            78.8
# gc_vision_face_detections-as_%                       5.6
# clarifai_face_detections-as_%                       22.8

# %% [markdown]
# # TODO
#
# * Move this to colab
# * Automated data packaging
# * Move training to Google Cloud ML Engine
# * Imbalanced classes
# * No test dataset

# %% [markdown]
# export GOOGLE_APPLICATION_CREDENTIALS="/home/josh/repos/assembly_melt/MELT-3265e45c6462.json"
